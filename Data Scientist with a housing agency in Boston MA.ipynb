# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkST0151ENSkillsNetwork20531532-2022-01-01" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# #### Import the required libraries we need for the lab.

# %%
import piplite
await piplite.install(['numpy'],['pandas'])
await piplite.install(['seaborn'])

# %%
import pandas as pd
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as pyplot
import scipy.stats
import statsmodels.api as sm
from statsmodels.formula.api import ols
# Out:
# <ipython-input-2-b3fdaf15785b>:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# #### Read the dataset in the csv file from the URL

# %%
from js import fetch
import io

URL = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-ST0151EN-SkillsNetwork/labs/boston_housing.csv'
resp = await fetch(URL)
boston_url = io.BytesIO((await resp.arrayBuffer()).to_py())

# %%
df=pd.read_csv(boston_url)

# %% [markdown]
# #### Add your code below following the instructions given in the course to complete the peer graded assignment

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  506 non-null    int64
#  1   CRIM        506 non-null    float64
#  2   ZN          506 non-null    float64
#  3   INDUS       506 non-null    float64
#  4   CHAS        506 non-null    float64
#  5   NOX         506 non-null    float64
#  6   RM          506 non-null    float64
#  7   AGE         506 non-null    float64
#  8   DIS         506 non-null    float64
#  9   RAD         506 non-null    float64
#  10  TAX         506 non-null    float64
#  11  PTRATIO     506 non-null    float64
#  12  LSTAT       506 non-null    float64
#  13  MEDV        506 non-null    float64
# dtypes: float64(13), int64(1)
# memory usage: 55.4 KB

# %%
df.describe()
# Out:
#        Unnamed: 0        CRIM          ZN       INDUS        CHAS         NOX  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean   252.500000    3.613524   11.363636   11.136779    0.069170    0.554695
# std    146.213884    8.601545   23.322453    6.860353    0.253994    0.115878
# min      0.000000    0.006320    0.000000    0.460000    0.000000    0.385000
# 25%    126.250000    0.082045    0.000000    5.190000    0.000000    0.449000
# 50%    252.500000    0.256510    0.000000    9.690000    0.000000    0.538000
# 75%    378.750000    3.677083   12.500000   18.100000    0.000000    0.624000
# max    505.000000   88.976200  100.000000   27.740000    1.000000    0.871000
#
#                RM         AGE         DIS         RAD         TAX     PTRATIO  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     6.284634   68.574901    3.795043    9.549407  408.237154   18.455534
# ...

# %%
sns.boxplot(x='MEDV',data=df).set(title='Median value of owner-occupied homes')
# Out:
# [Text(0.5, 1.0, 'Median value of owner-occupied homes')]

# %% [markdown]
# Outliers after third quartile.

# %%
ax2 = sns.countplot(x = 'CHAS', data = df)
ax2.set_title('Number of homes near the Charles River')
# Out:
# Text(0.5, 1.0, 'Number of homes near the Charles River')

# %% [markdown]
# The graph shows the majority of the houses are not near the Charles river.

# %%
df.loc[(df['AGE'] <= 35), 'age_group'] = '35 years and younger'
df.loc[(df['AGE'] > 35)&(df['AGE'] < 70), 'age_group'] = 'between 35 and 70 years'
df.loc[(df['AGE'] >= 70), 'age_group'] = '70 years and older'
df
# Out:
#      Unnamed: 0     CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  \
# 0             0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0
# 1             1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0
# 2             2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0
# 3             3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0
# 4             4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0
# ..          ...      ...   ...    ...   ...    ...    ...   ...     ...  ...
# 501         501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0
# 502         502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0
# 503         503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0
# 504         504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0
# 505         505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0
#
# ...

# %%
ax3 = sns.boxplot(x = 'MEDV', y = 'age_group', data = df)
ax3.set_title('Median value of owner-occupied homes per Age Group')
# Out:
# Text(0.5, 1.0, 'Median value of owner-occupied homes per Age Group')

# %% [markdown]
# The boxplot graph depicts that Median value of homes in the younger bracket (35 and younger) is on average more expensive than those in the next 2 brackets, additionally it's shown that the group of 70 it's median value is the lowest of the 3 groups.

# %%
sns.scatterplot(x='NOX', y='INDUS', data=df).set(title="Relationship between Nitric oxide and INDUS*")
# Out:
# [Text(0.5, 1.0, 'Relationship between Nitric oxide and INDUS*')]

# %% [markdown]
# The scatter plots reflects a positive linear relationship between the NOX and INDUS*

# %%
sns.histplot(x='PTRATIO', bins=10, kde=False, data=df).set(title="Pupil-teacher ratio by town")
# Out:
# [Text(0.5, 1.0, 'Pupil-teacher ratio by town')]

# %% [markdown]
# The Histogramm graph shows the most repeated value in the Pupil-teacher ratio is at 21.

# %% [markdown]
# Null hypo: There's no significant difference between the proximity to Charles river and the median value.
#
# Alternative Hypo: There IS significant difference between the proximity of the Charles river and the median value.

# %%
df.loc[(df['CHAS'] == 0), 'CRiver'] = 'Far'
df.loc[(df['CHAS'] == 1), 'CRiver'] = 'Close'
df.head(5)
# Out:
#    Unnamed: 0     CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  \
# 0           0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0
# 1           1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0
# 2           2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0
# 3           3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0
# 4           4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0
#
#      TAX  PTRATIO  LSTAT  MEDV CRiver
# 0  296.0     15.3   4.98  24.0    Far
# 1  242.0     17.8   9.14  21.6    Far
# 2  242.0     17.8   4.03  34.7    Far
# 3  222.0     18.7   2.94  33.4    Far
# 4  222.0     18.7   5.33  36.2    Far

# %%
scipy.stats.ttest_ind(df[df['CRiver'] == 'Far']['MEDV'], 
                      df[df['CRiver'] == 'Close']['MEDV'], equal_var = True)
# Out:
# TtestResult(statistic=-3.996437466090509, pvalue=7.390623170519905e-05, df=504.0)

# %% [markdown]
# "Given the pvalue of 7.39e-05, pvalue <0.005, the Null hypothesis is rejected, there's enough evince to correlate the poriximity to Charles river and the increase in the median value of the homes.

# %% [markdown]
# Question 7
#
# Null hypo: There's no difference in the Median value of homes for each portion of ownerr occupied units prior to 1940
#
# Alternative Hypo: There IS difference in the Median value of homes for each portion of ownerr occupied units prior to 1940

# %%
from statsmodels.formula.api import ols
lm = ols('MEDV ~ AGE', data = df).fit()
table = sm.stats.anova_lm(lm)
print(table)
# Out:
#              df        sum_sq      mean_sq          F        PR(>F)
# AGE         1.0   6069.761065  6069.761065  83.477459  1.569982e-18
# Residual  504.0  36646.534350    72.711378        NaN           NaN

# %% [markdown]
# Given the pvalue of 1.57e-18, pvalue <0.005, the Null hypothesis is rejected, there's enough evidence to correlate the median value of homes for each proportion of ownerr occupied units built prior to the 40s.

# %% [markdown]
# Question 8
# Null hypo: There's no correlation between NOX* and INDUS*
# Alternative Hypo: There IS a correlation between NOX* and INDUS*

# %%
scipy.stats.pearsonr(df['NOX'], df['INDUS'])
# Out:
# PearsonRResult(statistic=0.7636514469209192, pvalue=7.913361061210442e-98)

# %% [markdown]
# Given the pvalue of 7.92e-98, pvalue <0.005, the Null hypothesis is rejected, we can conclude there's enough evidence to show a correlation between theNOX and INDUS.

# %% [markdown]
# Question 9

# %%
X = df['DIS']
## y is the target/dependent variable
y = df['MEDV']
## add an intercept (beta_0) to our model
X = sm.add_constant(X) 

model = sm.OLS(y, X).fit()
predictions = model.predict(X)
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   MEDV   R-squared:                       0.062
# Model:                            OLS   Adj. R-squared:                  0.061
# Method:                 Least Squares   F-statistic:                     33.58
# Date:                Sun, 19 Jan 2025   Prob (F-statistic):           1.21e-08
# Time:                        16:31:53   Log-Likelihood:                -1823.9
# No. Observations:                 506   AIC:                             3652.
# Df Residuals:                     504   BIC:                             3660.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         18.3901      0.817     22.499      0.000      16.784      19.996
# ...

# %% [markdown]
# Given the square root of R-squared is  0.24899799195977465  a week correletation between the weighted distance and the median value can be inferred
